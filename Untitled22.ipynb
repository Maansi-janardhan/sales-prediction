# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
data = pd.read_csv('retail_sales_dataset.csv')

# %%
# prompt: read data

data = pd.read_csv('retail_sales_dataset.csv')

# %%
data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
# @title Age

from matplotlib import pyplot as plt
data['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Price per Unit vs Total Amount

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Price per Unit', y='Total Amount', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Total amount spent by age

import matplotlib.pyplot as plt
_ = plt.scatter(data['Age'], data['Total Amount'], c=data['Age'])

# %%
# @title Total Amount Spent Over Time

sns.lineplot(data=data, x="Date", y="Total Amount")
# Out:
# <Axes: xlabel='Date', ylabel='Total Amount'>

# %%
# @title Transaction ID

from matplotlib import pyplot as plt
data['Transaction ID'].plot(kind='line', figsize=(8, 4), title='Transaction ID')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Date vs Total Amount

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Total Amount']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Total Amount')

# %%
# @title Quantity vs Price per Unit

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Quantity', y='Price per Unit', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
data['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
print(data.describe())
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
print(data.dtypes)
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
non_numeric_cols = data.select_dtypes(include=["object"]).columns
data[non_numeric_cols].head()
# Out:
#   Customer ID  Gender Product Category
# 0     CUST001    Male           Beauty
# 1     CUST002  Female         Clothing
# 2     CUST003    Male      Electronics
# 3     CUST004    Male         Clothing
# 4     CUST005    Male           Beauty

# %%
for col in non_numeric_cols:
    data[col] = pd.to_numeric(data[col], errors="coerce")

# %%
# Mean
print("Mean:")
print(data.mean())

# Median
print("\nMedian:")
print(data.median())

# Mode
print("\nMode:")
print(data.mode())

# Standard Deviation
print("\nStandard Deviation:")
print(data.std())
# Out:
# Mean:
# Transaction ID                              500.5
# Date                2023-07-03 00:25:55.200000256
# Customer ID                                   NaN
# Gender                                        NaN
# Age                                        41.392
# Product Category                              NaN
# Quantity                                    2.514
# Price per Unit                             179.89
# Total Amount                                456.0
# dtype: object
#
# Median:
# Transaction ID                    500.5
# Date                2023-06-29 12:00:00
# Customer ID                         NaN
# Gender                              NaN
# Age                                42.0
# Product Category                    NaN
# Quantity                            3.0
# Price per Unit                     50.0
# Total Amount                      135.0
# dtype: object
#
# Mode:
#      Transaction ID       Date  Customer ID  Gender   Age  Product Category  \
# ...

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
figure = px.bar(data_frame=data,
                x = "Gender",
                y = "Age",
                title= "Transaction ID")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure = px.bar(data_frame=data,
                x = "Gender",
                y = "Product Category",
                title= "Transaction ID")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
